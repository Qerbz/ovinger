# %% [markdown]
# # The Gibbs phenomenon
#
# Let's load some useful packages and functions, as usual:

# %%
import numpy as np 
import matplotlib.pyplot as plt
from math import pi
plt.rcParams['figure.figsize'] = [15, 9]

# %% [markdown]
# Below, we define the function $f(x)$, as well as the expressions for the $a_n$ and $b_n$ coefficients:

# %%
def f(x):
     return x**2#insert the function of which you compute the Fourier Series
    
def a(n):
     return (4*(-1)**n)/(n**2)#insert an expression for a_n in terms of n (n>0)
    
def b(n):
    return 0 #insert an expression for b_n in terms of n (n>0)

# %% [markdown]
# With that, we can define the truncated Fourier series $S_N(x)$:

# %%
def trigonometricSeriesN(x, N, a0, a, b):
    # calculate the truncated Fourier series up to (including)
    # the N-th term (cos(N*pi*x), sin(N*pi*x)) in x
    # given the Fourier coefficients a_n, b_n by the functions
    # a(n) and b(n), and a_0 by a0
    a_ = [a0] + [a(n) for n in range(1,N)]
    b_ = [0] + [b(n) for n in range(1,N)]
    sum = a_[0]
    for n in range(1,N):
        sum += a_[n]*np.cos(n*x)+b_[n]*np.sin(n*x)
    return sum

# %% [markdown]
# We finally specify the remaining data:

# %%
#Remaining problem data
a0 = (1/3)*np.pi**2#insert the value of the a0 coefficient
N = 1000 #truncation of series
x = np.linspace(-np.pi,np.pi,50000) #many equally-spaced sampling points
y = f(x) #evaluate the exact function f(x) at all points in x
# compute the truncated Fourier series and plot it and the function f in one plot
plt.plot(x,y)

#Compute error
x = np.linspace(-np.pi,np.pi,50000) #many equally-spaced sampling points (x>=0)
y = f(x) #evaluate the exact function f(x) at all points in x
sN = trigonometricSeriesN(x, 20, a0, a, b) #evaluate the truncated trigonometric series S_N(x) at all points in x
plt.plot(x,sN)

# %%
a(0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /Users/patrick/repos/assignment9/gibbs copy.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/Users/patrick/repos/assignment9/gibbs%20copy.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> a(0)
#
# /Users/patrick/repos/assignment9/gibbs copy.ipynb Cell 9 line 5
#       <a href='vscode-notebook-cell:/Users/patrick/repos/assignment9/gibbs%20copy.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> def a(n):
# ----> <a href='vscode-notebook-cell:/Users/patrick/repos/assignment9/gibbs%20copy.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a>      return (4*(-1)**n)/(n**2)
#
# ZeroDivisionError: division by zero
